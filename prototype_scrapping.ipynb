# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

# Function to clean up folder and filenames
def clean_filename(url):
    # Use the URL path as the filename, replacing slashes with underscores
    return urlparse(url).path.replace('/', '_').strip('_')

# Recursive function to scrape a URL and follow links up to depth 4
def scrape_page(url, current_depth, max_depth, parent_directory):
    if current_depth > max_depth:
        return

    # Create a directory for the current URL if it doesn't exist
    directory_name = clean_filename(url)
    directory_path = os.path.join(parent_directory, directory_name)
    os.makedirs(directory_path, exist_ok=True)

    # Fetch the page content
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Save the main content (paragraphs) to a .txt file
        text_filename = os.path.join(directory_path, f'{directory_name}.txt')
        with open(text_filename, 'w', encoding='utf-8') as file:
            main_content = soup.find_all('p')
            for paragraph in main_content:
                file.write(paragraph.get_text() + '\n')

        print(f'Scraped: {url} (depth {current_depth})')

        # Find all links on the page
        links = soup.find_all('a', href=True)
        for link in links:
            full_url = urljoin(url, link['href'])  # Get the full URL
            # Ensure we are only following internal links (same domain)
            if urlparse(full_url).netloc == urlparse(url).netloc:
                # Recursively scrape the link
                scrape_page(full_url, current_depth + 1, max_depth, directory_path)

    except requests.RequestException as e:
        print(f"Error accessing {url}: {e}")

# %%
# Initial settings
root_url = 'https://www.ontario.ca/page/driving-and-roads'
root_directory = 'ontarioRoadSafety'  # Root folder for storing scraped data
max_depth = 2  # Outline how many layers deep to read

# %%
# Create the root directory if it doesn't exist
os.makedirs(root_directory, exist_ok=True)

# %%
# Start scraping from the root URL
scrape_page(root_url, current_depth=0, max_depth=max_depth, parent_directory=root_directory)
# Out:
# Scraped: https://www.ontario.ca/page/driving-and-roads (depth 0)
# Scraped: https://www.ontario.ca/page/driving-and-roads#main-content (depth 1)
# Scraped: https://www.ontario.ca/page/driving-and-roads#main-content (depth 2)
# Scraped: https://www.ontario.ca/page/government-ontario (depth 2)
# Scraped: https://www.ontario.ca/fr/page/conduite-et-routes (depth 2)
# Scraped: https://www.ontario.ca/fr/page/conduite-et-routes (depth 2)
# Scraped: https://www.ontario.ca/page/arts-and-culture (depth 2)
# Scraped: https://www.ontario.ca/page/business-and-economy (depth 2)
# Scraped: https://www.ontario.ca/covid (depth 2)
# Scraped: https://www.ontario.ca/page/driving-and-roads (depth 2)
# Scraped: https://www.ontario.ca/page/education-and-training (depth 2)
# Scraped: https://www.ontario.ca/page/environment-and-energy (depth 2)
# Scraped: https://www.ontario.ca/page/government (depth 2)
# Scraped: https://www.ontario.ca/page/health-care-ontario (depth 2)
# Scraped: https://www.ontario.ca/page/home-and-community (depth 2)
# Scraped: https://www.ontario.ca/page/jobs-and-employment (depth 2)
# Scraped: https://www.ontario.ca/page/law-and-safety (depth 2)
# Scraped: https://www.ontario.ca/page/rural-and-north (depth 2)
# Scraped: https://www.ontario.ca/page/taxes-and-benefits (depth 2)
# Scraped: https://www.ontario.ca/page/travel-and-recreation (depth 2)
# Scraped: https://www.ontario.ca/page/government-ontario (depth 2)
# Scraped: https://www.ontario.ca/page/renew-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/paying-defaulted-fines-and-drivers-licence-reinstatement (depth 2)
# Scraped: https://www.ontario.ca/page/renew-expired-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/renew-g-drivers-licence-80-years-and-over (depth 2)
# Scraped: https://www.ontario.ca/page/change-information-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/replace-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/medical-review-ontario-drivers (depth 2)
# Scraped: https://www.ontario.ca/page/drive-ontario-visitors (depth 2)
# Scraped: https://www.ontario.ca/page/renew-drivers-licence-outside-ontario (depth 2)
# Scraped: https://www.ontario.ca/page/exchange-out-province-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/get-g-drivers-licence-new-drivers (depth 2)
# Scraped: https://www.ontario.ca/page/get-motorcycle-licence (depth 2)
# Scraped: https://www.ontario.ca/document/official-mto-drivers-handbook (depth 2)
# Scraped: https://www.ontario.ca/page/government-approved-driving-schools (depth 2)
# Scraped: https://www.ontario.ca/page/get-truck-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page
de-lontario (depth 2)
# Scraped: https://www.ontario.ca/fr/page/conduire-en-ontario-visiteurs (depth 2)
# Scraped: https://www.ontario.ca/fr/page/renouveler-un-permis-de-conduire-pendant-un-sejour-lexterieur-de-lontario (depth 2)
# Scraped: https://www.ontario.ca/fr/page/echange-dun-permis-de-conduire-non-delivre-par-la-province-de-lontario (depth 2)
# Scraped: https://www.ontario.ca/fr/page/obtenir-un-permis-de-conduire-g-conducteurs-novices (depth 2)
# Scraped: https://www.ontario.ca/fr/page/obtenir-un-permis-moto (depth 2)
# Scraped: https://www.ontario.ca/fr/document/guide-officiel-de-lautomobiliste (depth 2)
# Scraped: https://www.ontario.ca/fr/page/ecoles-de-conduite-agreees-par-le-gouvernement (depth 2)
# Scraped: https://www.ontario.ca/fr/page/obtenir-un-permis-de-conduire-pour-camion (depth 2)
# Scraped: https://www.ontario.ca/fr/page/obtenir-un-permis-de-conduire-dautobus (depth 2)
# Scraped: https://www.ontario.ca/fr/page/normes-medicales-de-vision-et-daudition-pour-les-conducteurs-de-vehicules-commerciaux (depth 2)
# Scraped: https://www.ontario.ca/fr/page/vehicules-utilitaires (depth 2)
# Scraped: https://www.ontario.ca/fr/page/fonctionnement-des-points-dinaptitude (depth 2)
# Scraped: https://www.ontario.ca/fr/page/comment-retablir-un-permis-de-conduire-qui-ete-suspendu (depth 2)
# Scraped: https://www.ontario.ca/fr/page/acheter-ou-vendre-un-vehicule-doccasion-en-ontario (depth 2)
# Scraped: https://www.ontario.ca/fr/page/immatriculer-et-assurer-un-vehicule-en-ontario (depth 2)
# Scraped: https://www.ontario.ca/fr/page/plaque-dimmatriculation-personnalisee (depth 2)
# Scraped: https://www.ontario.ca/fr/page/remplacer-une-plaque-dimmatriculation-perdue-volee-ou-endommagee (depth 2)
# Scraped: https://www.ontario.ca/fr/page/modifier-des-renseignements-sur-un-certificat-dimmatriculation (depth 2)
# Scraped: https://www.ontario.ca/fr/page/resume-de-dossier-de-vehicule-non-certifie (depth 2)
# Scraped: https://www.ontario.ca/fr/page/renouvellement-des-plaques-dimmatriculation (depth 2)
# Scraped: https://www.ontario.ca/fr/page/inspection-le-programme-dinspection-des-emissions-et-de-la-securite (depth 2)
# Scraped: https://www.ontario.ca/fr/page/obtenir-un-dossier-de-conduite (depth 2)
# Scraped: https://www.ontario.ca/fr/page/obtenir-des-dossiers-de-conduite-long-terme-ou-des-lettres-et-documents (depth 2)
# Scraped: https://www.ontario.ca/fr/page/obtenir-un-rapport-concernant-une-collision (depth 2)
# Scraped: https://www.ontario.ca/fr/page/immatriculation-dutilisateur-de-vehicule-utilitaire-iuvu (depth 2)
# Scraped: https://www.ontario.ca/fr/page/obtenir-un-permis-de-stationnement-accessible (depth 2)
# Scraped: https://www.ontario.ca/fr/page/renouvellement-remplacement-ou-modification-de-renseignements-sur-un-permis-de-stationnement (depth 2)
# Scraped: https://www.ontario.ca/fr/page/vos-droits-lors-de-lobtention-de-services-de-remorquage (depth 2)
# Scraped: https://www.ontario.ca/fr/page/programme-pilote-des-zones-de-depannage (depth 2)
# Scraped: https://www.ontario.ca/fr/page/exigences-en-matiere-de-remorquage-et-dentreposage-des-vehicules (depth 2)
# Scraped: https://www.ontario.ca/511 (depth 2)
# Scraped: https://www.ontario.ca/fr/page/ministere-des-transports (depth 2)
# Scraped: https://www.ontario.ca/fr/page/serviceontario (depth 2)
# Scraped: https://www.ontario.ca/fr/page/ministere-de-linfrastructure (depth 2)
# Scraped: https://www.ontario.ca/fr/page/lontario-en-bref (depth 2)
# Scraped: https://www.ontario.ca/fr/page/accessibilite (depth 2)
# Scraped: https://www.ontario.ca/fr/page/declaration-concernant-la-protection-de-la-vie-privee (depth 2)
# Scraped: https://www.ontario.ca/fr/page/conditions-dutilisation (depth 2)
# Scraped: https://www.ontario.ca/fr/page/droits-dauteur (depth 2)
# Scraped: https://www.ontario.ca/fr/page/conduite-et-routes (depth 1)
# Scraped: https://www.ontario.ca/fr/page/conduite-et-routes#main-content (depth 2)
# Scraped: https://www.ontario.ca/fr/page/gouvernement-de-lontario (depth 2)
# Scraped: https://www.ontario.ca/page/driving-and-roads (depth 2)
# Scraped: https://www.ontario.ca/page/driving-and-roads (depth 2)
# Scraped: https://www.ontario.ca
ontario (depth 2)
# Scraped: https://www.ontario.ca/page/accessibility (depth 2)
# Scraped: https://www.ontario.ca/page/privacy-statement (depth 2)
# Scraped: https://www.ontario.ca/page/terms-use (depth 2)
# Scraped: https://www.ontario.ca/page/copyright-information (depth 2)
# Scraped: https://www.ontario.ca/page/driving-and-roads (depth 1)
# Scraped: https://www.ontario.ca/page/driving-and-roads#main-content (depth 2)
# Scraped: https://www.ontario.ca/page/government-ontario (depth 2)
# Scraped: https://www.ontario.ca/fr/page/conduite-et-routes (depth 2)
# Scraped: https://www.ontario.ca/fr/page/conduite-et-routes (depth 2)
# Scraped: https://www.ontario.ca/page/arts-and-culture (depth 2)
# Scraped: https://www.ontario.ca/page/business-and-economy (depth 2)
# Scraped: https://www.ontario.ca/covid (depth 2)
# Scraped: https://www.ontario.ca/page/driving-and-roads (depth 2)
# Scraped: https://www.ontario.ca/page/education-and-training (depth 2)
# Scraped: https://www.ontario.ca/page/environment-and-energy (depth 2)
# Scraped: https://www.ontario.ca/page/government (depth 2)
# Scraped: https://www.ontario.ca/page/health-care-ontario (depth 2)
# Scraped: https://www.ontario.ca/page/home-and-community (depth 2)
# Scraped: https://www.ontario.ca/page/jobs-and-employment (depth 2)
# Scraped: https://www.ontario.ca/page/law-and-safety (depth 2)
# Scraped: https://www.ontario.ca/page/rural-and-north (depth 2)
# Scraped: https://www.ontario.ca/page/taxes-and-benefits (depth 2)
# Scraped: https://www.ontario.ca/page/travel-and-recreation (depth 2)
# Scraped: https://www.ontario.ca/page/government-ontario (depth 2)
# Scraped: https://www.ontario.ca/page/renew-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/paying-defaulted-fines-and-drivers-licence-reinstatement (depth 2)
# Scraped: https://www.ontario.ca/page/renew-expired-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/renew-g-drivers-licence-80-years-and-over (depth 2)
# Scraped: https://www.ontario.ca/page/change-information-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/replace-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/medical-review-ontario-drivers (depth 2)
# Scraped: https://www.ontario.ca/page/drive-ontario-visitors (depth 2)
# Scraped: https://www.ontario.ca/page/renew-drivers-licence-outside-ontario (depth 2)
# Scraped: https://www.ontario.ca/page/exchange-out-province-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/get-g-drivers-licence-new-drivers (depth 2)
# Scraped: https://www.ontario.ca/page/get-motorcycle-licence (depth 2)
# Scraped: https://www.ontario.ca/document/official-mto-drivers-handbook (depth 2)
# Scraped: https://www.ontario.ca/page/government-approved-driving-schools (depth 2)
# Scraped: https://www.ontario.ca/page/get-truck-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/get-bus-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/medical-vision-and-hearing-standards-commercial-drivers (depth 2)
# Scraped: https://www.ontario.ca/page/commercial-vehicles (depth 2)
# Scraped: https://www.ontario.ca/page/understanding-demerit-points (depth 2)
# Scraped: https://www.ontario.ca/page/reinstate-suspended-drivers-licence (depth 2)
# Scraped: https://www.ontario.ca/page/buy-or-sell-used-vehicle-ontario (depth 2)
# Scraped: https://www.ontario.ca/page/register-and-insure-vehicle-ontario (depth 2)
# Scraped: https://www.ontario.ca/page/personalized-licence-plate (depth 2)
# Scraped: https://www.ontario.ca/page/replace-lost-stolen-or-damaged-licence-plate-or-personalized-licence-plate (depth 2)
# Scraped: https://www.ontario.ca/page/change-information-vehicle-permit (depth 2)
# Scraped: https://www.ontario.ca/page/uncertified-vehicle-record (depth 2)
# Scraped: https://www.ontario.ca/page/licence-plate-renewals (depth 2)
# Scraped: https://www.ontario.ca/page/driveon-emissions-and-safety-inspection-program (depth 2)
# Scraped: https://www.ontario.ca/page/get-driving-record (depth 2)
# Scraped: https://www.ontario.ca/page/get-longer-term-driving-records-or-letters-and-documents (depth 2)
ontario (depth 2)
# Scraped: https://www.ontario.ca/page/accessibility (depth 2)
# Scraped: https://www.ontario.ca/page/privacy-statement (depth 2)
# Scraped: https://www.ontario.ca/page/terms-use (depth 2)
# Scraped: https://www.ontario.ca/page/copyright-information (depth 2)
# Scraped: https://www.ontario.ca/page/environment-and-energy (depth 1)
# Scraped: https://www.ontario.ca/page/environment-and-energy#main-content (depth 2)
# Scraped: https://www.ontario.ca/page/government-ontario (depth 2)
# Scraped: https://www.ontario.ca/fr/page/environnement-et-energie (depth 2)
# Scraped: https://www.ontario.ca/fr/page/environnement-et-energie (depth 2)
# Scraped: https://www.ontario.ca/page/arts-and-culture (depth 2)
# Scraped: https://www.ontario.ca/page/business-and-economy (depth 2)
# Scraped: https://www.ontario.ca/covid (depth 2)
# Scraped: https://www.ontario.ca/page/driving-and-roads (depth 2)
# Scraped: https://www.ontario.ca/page/education-and-training (depth 2)
# Scraped: https://www.ontario.ca/page/environment-and-energy (depth 2)
# Scraped: https://www.ontario.ca/page/government (depth 2)
# Scraped: https://www.ontario.ca/page/health-care-ontario (depth 2)
# Scraped: https://www.ontario.ca/page/home-and-community (depth 2)
# Scraped: https://www.ontario.ca/page/jobs-and-employment (depth 2)
# Scraped: https://www.ontario.ca/page/law-and-safety (depth 2)
# Scraped: https://www.ontario.ca/page/rural-and-north (depth 2)
# Scraped: https://www.ontario.ca/page/taxes-and-benefits (depth 2)
# Scraped: https://www.ontario.ca/page/travel-and-recreation (depth 2)
# Scraped: https://www.ontario.ca/page/government-ontario (depth 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Start scraping from the root URL
# ----> 2 scrape_page(root_url, current_depth=0, max_depth=max_depth, parent_directory=root_directory)
#
# Cell In[1], line 42, in scrape_page(url, current_depth, max_depth, parent_directory)
#      39         # Ensure we are only following internal links (same domain)
#      40         if urlparse(full_url).netloc == urlparse(url).netloc:
#      41             # Recursively scrape the link
# ---> 42             scrape_page(full_url, current_depth + 1, max_depth, directory_path)
#      44 except requests.RequestException as e:
#      45     print(f"Error accessing {url}: {e}")
#
# Cell In[1], line 42, in scrape_page(url, current_depth, max_depth, parent_directory)
#      39         # Ensure we are only following internal links (same domain)
#      40         if urlparse(full_url).netloc == urlparse(url).netloc:
#      41             # Recursively scrape the link
# ---> 42             scrape_page(full_url, current_depth + 1, max_depth, directory_path)
#      44 except requests.RequestException as e:
#      45     print(f"Error accessing {url}: {e}")
#
# Cell In[1], line 23, in scrape_page(url, current_depth, max_depth, parent_directory)
#      21 # Fetch the page content
#      22 try:
# ---> 23     response = requests.get(url)
#      24     soup = BeautifulSoup(response.text, 'html.parser')
#      26     # Save the main content (paragraphs) to a .txt file
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/urllib3/connection.py:693, in HTTPSConnection.connect(self)
#     691 try:
#     692     sock: socket.socket | ssl.SSLSocket
# --> 693     self.sock = sock = self._new_conn()
#     694     server_hostname: str = self.host
#     695     tls_in_tls = False
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     194 """Establish a socket connection and set nodelay settings on it.
#     195
#     196 :return: New socket connection.
#     197 """
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#     206     raise NameResolutionError(self.host, self, e) from e
#
# File ~/aidi-1100/venv/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:
